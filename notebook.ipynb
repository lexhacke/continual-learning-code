# %%
# @ title Update Repository
# %cd /content/
import shutil

shutil.rmtree('continual-learning-coder', ignore_errors=True)

# !git clone https://github.com/lexhacke/continual-learning-coder.git
# %cd /content/continual-learning-coder
# !pip install -r requirements.txt
# Out:
# /content
# Cloning into 'continual-learning-coder'...
# fatal: could not read Username for 'https://github.com': No such device or address
# [Errno 2] No such file or directory: '/content/continual-learning-coder'
# /content
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !ls
# Out:
# sample_data

# %%
from qwen_sft import train_sdft

if __name__ == "__main__":
    from code_dataset import CodeFinetuneDataset
    # Load dataset
    dataset = CodeFinetuneDataset("https://github.com/psf/requests")
    print(f"Loaded {len(dataset)} samples")
    
    # Train with SDFT
    model = train_sdft(
        dataset,
        model_name="Qwen/Qwen2.5-Coder-7B-Instruct",
        batch_size=2,
        max_epochs=3,
    )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1370794196.py in <cell line: 0>()
# ----> 1 from qwen_sft import train_sdft
#       2
#       3 if __name__ == "__main__":
#       4     from code_dataset import CodeFinetuneDataset
#       5     # Load dataset
#
# ModuleNotFoundError: No module named 'qwen_sft'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
