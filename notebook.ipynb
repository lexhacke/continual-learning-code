# %%
# @ title Update Repository
# %cd /content/
import shutil

shutil.rmtree('continual-learning-coder', ignore_errors=True)

# !git clone https://github.com/lexhacke/continual-learning-coder.git
# %cd continual-learning-coder
# !pip install -r requirements.txt
# Out:
# /content
# Cloning into 'continual-learning-coder'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 10 (delta 0), reused 10 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (10/10), 6.85 KiB | 6.85 MiB/s, done.
# /content/continual-learning-coder
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 846.0/846.0 kB 16.7 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 44.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 68.0 MB/s eta 0:00:00
# ...

# %%
from qwen
# Out:
# code-dataset.py  notebook.ipynb  qwen-sft.py  README.md  requirements.txt
